# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/Python_Projects/blob/main/Python_Basic_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Write a program to check whether a number is even or odd.

class Solution:
  def is_even_odd(n):
    if n % 2 == 0:
      print("Even")
    else:
      print("Odd")

n = int(input("Enter a number:"))
Solution.is_even_odd(n)
# Out:
# Enter a number:15
# Odd

# %%
#Write a program to find the largest among three numbers.

def find_largest(a, b, c):
    if a >= b and a >= c:
        print("Largest number is:", a)
    elif b >= a and b >= c:
        print("Largest number is:", b)
    else:
        print("Largest number is:", c)


a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

find_largest(a, b, c)
# Out:
# Enter first number: 15
# Enter second number: 10
# Enter third number: 5
# Largest number is: 15

# %%
#Write a program to check if a number is prime.

def is_prime(n):
  if n < 2:
    return False

  for i in range(2,n):
    if n % i == 0:
      return False
    return True

n = int(input("Enter a number:"))
if is_prime(n):
  print("Prime")
else:
  print("Not Prime")
# Out:
# Enter a number:3
# Prime

# %%
#Write a program to reverse a given number.

def reverse_num(n):
  reverse = 0

  while n > 0:
    digit = n % 10
    reverse = reverse * 10 + digit
    n = n // 10

  return reverse

num = int(input("Enter a number:"))
print(reverse_num(num))
# Out:
# Enter a number:1234
# 4321

# %%
#Write a program to check whether a number is palindrome.

def is_palindrome(n):
  reverse = 0
  original = n
  while n > 0:
    digit = n % 10
    reverse = reverse * 10 + digit
    n = n // 10

  if original == reverse:
    print("Palindrome")
  else:
    print("No Palindrome")

num = int(input("Enter a number: "))
is_palindrome(num)
# Out:
# Enter a number: 121
# Palindrome

# %%
#Write a program to calculate the factorial of a number.

def factorial(n):
    result = 1

    for i in range(1, n + 1):
        result *= i

    return result


num = int(input("Enter a number: "))
print("Factorial:", factorial(num))
# Out:
# Enter a number: 2
# Factorial: 2

# %%
#Write a program to calculate the sum of digits of a number.

num = int(input("Enter a number:"))

sum_digits = 0

while num > 0:
  digit = num % 10
  sum_digits += digit
  num = num // 10

print("Sum of Digits:",sum_digits)
# Out:
# Enter a number:25
# Sum of Digits: 7

# %%
#Count Digits in a Number

num = int(input("Enter a number:"))

count_number = 0

while num > 0:
  count_number += 1
  num = num // 10
print("Digits:", count_number)
# Out:
# Enter a number:23456
# Digits: 5

# %%
#Write a program to determine whether a year is a leap year.

year = int(input("Enter a year:"))

if(year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
  print("Leap Year")
else:
  print("Not Leap Year")
# Out:
# Enter a year:2025
# Not Leap Year

# %%
#Print the first N numbers of the Fibonacci series.

n = int(input("Enter number of terms: "))

a = 0
b = 1

for i in range(n):
    print(a, end=" ")
    a, b = b, a + b
# Out:
# Enter number of terms: 7
# 0 1 1 2 3 5 8
