# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/Python_Projects/blob/main/Password_Generator_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile generator.py
import random
import string

def generate_password(length):
  characters = string.ascii_letters + string.digits + string.punctuation
  password = ""

  for i in range(length):
    password += random.choice(characters)

  return password

print(generate_password(12))
# Out:
# Writing generator.py

# %%
def generate_password(length, use_numbers=True, use_symbols=True, use_upper=True):
  characters = string.ascii_lowercase

  if use_upper:
    characters = string.ascii_uppercase

  if use_numbers:
    characters += string.digits

  if use_symbols:
    characters += string.punctuation

  password = ' '.join(random.choice(characters) for i in range(length))

  return password

# %%
from generator import generate_password

def main():
  try:
      length = int(input("Password Length: "))
  except ValueError:
      print("Please enter a valid number for password length.")
      return

  numbers = input("Include numbers? (y/n): ").lower() == "y"
  symbols = input("Include symbols? (y/n): ").lower() == "y"
  upper = input("Include uppercase letters? (y/n): ").lower() == "y"

  password = generate_password(length, numbers, symbols, upper)
  print("Generated password:", password)

if __name__ == "__main__":
  main()
# Out:
# Password Length: Pranay@12345
# Please enter a valid number for password length.

# %%
#Password Strength Checker

import string
def check_strength(password):
  score = 0

  if len(password) >= 12:
    score += 1

  if any(c in string.digits for c in password):
    score += 1

  if any(c in string.punctuation for c in password):
    score += 1

  if any(c in string.ascii_uppercase for c in password):
    score += 1

  if score == 4:
    return "Very Strong"

  elif score == 3:
    return "Strong"

  elif score == 2:
    return "Medium"

  else:
    return "Weak"

# %%
# Save Password

import json
FILE = "data/passwords.json"

def save_password(site, username, password):

  data = {
      "site": site,
      "username": username,
      "password": password
  }

  try:
    with open(FILE, "r") as f:
      passwords = json.load(f)
  except:
    passwords = []


  password.append(data)

  with open(FILE, "w") as f:
    json.dump(passwords,f)

# %%
import secrets
import string

def secure_passowrds(length):
  characters = string.ascii_letters + string.digits + string.punctuation

  password = " ".join(secrets.choice(characters) for i in range(length))

  return password

# %%
# !pip install pyperclip

# %%
import string
import secrets

def secure_passwords(length):
    characters = string.ascii_letters + string.digits + string.punctuation
    password = "".join(secrets.choice(characters) for i in range(length))
    return password

password = secure_passwords(12)

print("Generated Password:", password)
# Out:
# Generated Password: )9Y/Km42<0SJ

# %%
import secrets
import string

def generate_password(length):
    characters = string.ascii_letters + string.digits + string.punctuation
    return "".join(secrets.choice(characters) for _ in range(length))

length = int(input("Enter password length: "))
print("Generated password:", generate_password(length))
# Out:
# Enter password length: 12
# Generated password: F'>6I4eTC(,v
