# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/Python_Projects/blob/main/Python_Intermediate_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Implement Linear Search

numbers = [12, 45, 67, 89, 34, 22]

target = int(input("Enter number to search: "))

for index in range(len(numbers)):
    if numbers[index] == target:
        print("Found at index", index)
        break
else:
    print("Not Found")
# Out:
# Enter number to search: 45
# Found at index 1

# %%
#Find the Longest Word in a Sentence

sentence = input("Enter a sentence:")
words = sentence.split()
longest = ""

for word in words:
  if len(word) > len(longest):
    longest = word

print("Longest Word:",longest)
# Out:
# Enter a sentence:My name is Pranay Shukla
# Longest Word: Pranay

# %%
#Count the Occurrence of Each Word

sentence = input("Enter a sentence:")
words = sentence.split()
count = 0

for word in words:
  count += 1
  print(word, ":", words.count(word))
# Out:
# Enter a sentence:My name is Pranay Shukla. My hobby is to listen music. I love to listen soft music mostly
# My : 2
# name : 1
# is : 2
# Pranay : 1
# Shukla. : 1
# My : 2
# hobby : 1
# is : 2
# to : 2
# listen : 2
# music. : 1
# I : 1
# love : 1
# to : 2
# listen : 2
# soft : 1
# music : 1
# mostly : 1

# %%
#Find Common Elements in Two Lists

list1 = [1,2,3,4,5]
list2 = [3,5,7,9]

common = []

for i in list1:
  if i in list2:
    common.append(i)

print(common)
# Out:
# [3, 5]

# %%
#Sort a List Without Using sort()

numbers = [23, 11, 78, 45, 2]

for i in range(len(numbers)):
  for j in range(i+1,len(numbers)):
    if numbers[i] > numbers[j]:
      numbers[i], numbers[j] = numbers[j], numbers[i]
print(numbers)
# Out:
# [2, 11, 23, 45, 78]

# %%
#Count Vowels and Consonants

text = input("Enter a text:").lower()
vowels = 0
consonants = 0

for char in text:
  if char.isalpha():
    if char in "aeiou":
      vowels += 1
    else:
      consonants += 1

print("Vowels",vowels)
print("Consonants",consonants)
# Out:
# Enter a text:Pranay Shukla
# Vowels 4
# Consonants 8

# %%
#. Check Whether Two Strings are Anagrams
str1 = input("Enter a string:")
str2 = input("Enter a string:")

if sorted(str1) == sorted(str2):
  print("Anagram")
else:
  print("Not Anagram")
# Out:
# Enter a string:listen
# Enter a string:silent
# Anagram

# %%
#Find Duplicate Elements in a List

numbers = [1,2,2,3,3,4,5,6,7,7,7,8]
duplicates = set()

for num in range(len(numbers)):
  if numbers.count(num) > 1:
    duplicates.add(num)

print("Duplicates:",duplicates)
# Out:
# Duplicates: {2, 3, 7}

# %%
#Check if a Number is an Armstrong Number

num = int(input("Enter a number:"))

original = num
digits = len(str(num))
total = 0

while num > 0:
  digit = num % 10
  total += digit ** digits
  num //= 10

if total == original:
  print("Armstrong Number")
else:
  print("Not a Armstrong Number")
# Out:
# Enter a number:153
# Armstrong Number

# %%
#Check if a String is a Palindrome

text = input("Enter a text:")

reverse = ""

for ch in text:
  reverse = ch + reverse

if reverse == text:
  print("Palindrome")
else:
  print("Not a Palindrome")
# Out:
# Enter a text:Hii
# Not a Palindrome
