# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/Python_Projects/blob/main/Python_Practice_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Find the First Repeating Character

text = input("Enter a string:")

seen = set()

for char in text:
  if char in seen:
    print("First Repeating Character:",char)
    break
  else:
    seen.add(char)
else:
  ("No Repeating Character Found")
# Out:
# Enter a string:Pranay
# First Repeating Character: a

# %%
#Remove All Vowels from a String

text = input("Enter a string:")

result = ""

for ch in text:
  if ch.lower() not in 'aeiou':
    result += ch

print(result)
# Out:
# Enter a string:Pranay
# Prny

# %%
#Check Whether a String Contains Only Digits

text = input("Enter a string:")

if text.isdigit():
  print("The string contains only digits")
else:
  print("The string does not contain only digits")
# Out:
# Enter a string:12345
# The string contains only digits

# %%
#Replace Spaces with Hyphens

text = input("Enter a string:")

result = ""

for ch in text:
  if ch == " ":
    result += "-"
  else:
    result += ch

print(result)
# Out:
# Enter a string:Python is easy
# Python-is-easy

# %%
#Count the Frequency of Each Word

text = input("Enter a string:")

words = text.split()

freq = {}

for char in words:
  if char in freq:
    freq[char] += 1
  else:
    freq[char] = 1

print(freq)
# Out:
# Enter a string:I Love my Country. My Country is India
# {'I': 1, 'Love': 1, 'my': 1, 'Country.': 1, 'My': 1, 'Country': 1, 'is': 1, 'India': 1}

# %%
#Check Whether One String is a Rotation of Another

str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

if len(str1) == len(str2) and str2 in (str1 + str1):
    print("Rotation")
else:
    print("Not Rotation")
# Out:
# Enter first string: silent
# Enter second string: listen
# Not Rotation

# %%
#Capitalize the First Letter of Every Word

text = input("Enter a string:")

words = text.split()

result = ""

for word in words:
  result += word.capitalize() + " "
print(result)
# Out:
# Enter a string:my name is pranay shukla
# My Name Is Pranay Shukla
