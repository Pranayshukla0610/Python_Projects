# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/Python_Projects/blob/main/Banking_System_OOPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Build a banking system with:

#Features:
#Create users
#Multiple account types (Savings, Current)
#Deposit, Withdraw
#Transfer money
#Transaction history
#Custom print
#Operator overloading (merge accounts)
#Iterator for transactions


class Account:
  def __init__(self,name,balance):
    self.name = name
    self.balance = balance
    self.transactions = []

  def deposit(self,amount):
    self.balance += amount
    self.transactions.append(f"Deposited {amount}")

  def withdraw(self,amount):
    if self.amount > self.balance:
      print("Insufficient Balance")
    else:
      self.balance -= amount
      self.transactions.append(f"Withdraw {amount}")

# %%
class SavingsAccount(Account):
  def __init__(self,name,balance,interest_rate):
    super().__init__(name,balance)
    self.interest_rate = interest_rate

  def add_interest(self):
    interest = self.balance * self.interest_rate
    self.balance += interest
    self.transactions.append(f"Added Interest {interest}")

# %%
class CurrentAccount(Account):
  def __init__(self, name, balance, overdraft_limit):
    super().__init__(name,balance)
    self.overdraft_limit = overdraft_limit

  def withdraw(self,amount):
    if amount > self.balance + self.overdraft_limit:
      print("Overdraft Limit Exceed")
    else:
      self.balance -= amount
      self.transactions.append(f"Withdrew {amount}")

# %%
#Iterator for Transactions

class Account:
  def __iter__(self):
    self.index = 0
    return self

  def __next__(self):
    if self.__index < len(self.transactions):
      result = self.transactions[self._index]
      self._index += 1
      return result
    else:
      raise StopIteration

# %%
def transfer(self, other, amount):
    if self.balance >= amount:
        self.balance -= amount
        other.balance += amount
        self.transactions.append(f"Transferred {amount} to {other.name}")
        other.transactions.append(f"Received {amount} from {self.name}")
    else:
        print("Transfer failed")
