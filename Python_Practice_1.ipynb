# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranayshukla0610/Python_Projects/blob/main/Python_Practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Check if a Number is Even or Odd

num = int(input("Enter a number:"))

if num % 2 == 0:
  print("Even Number")
else:
  print("Odd Number")
# Out:
# Enter a number:21
# Odd Number

# %%
#Find the Largest of Two Numbers

num1 = int(input("Enter first number:"))
num2 = int(input("Enter second number:"))

if num1 > num2:
  print(num1, "is greater than", num2)
else:
  print(num2, "is greater than", num1)
# Out:
# Enter first number:21
# Enter second number:50
# 50 is greater than 21

# %%
#Find the Largest of Three Numbers

num1 = int(input("Enter first number:"))
num2 = int(input("Enter second number:"))
num3 = int(input("Enter third number:"))

if num1 > num2 and num1 > num3:
  print(num1, "is greater than", num2, "and", num3)
elif num2 > num1 and num2 > num3:
  print(num2, "is greater than", num1, "and", num3)
else:
  print(num3, "is greater than", num2, "and", num1)
# Out:
# Enter first number:22
# Enter second number:21
# Enter third number:30
# 30 is greater than 21 and 22

# %%
#Find the Smallest of Three Numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a <= b and a <= c:
    print("Smallest number is:", a)
elif b <= a and b <= c:
    print("Smallest number is:", b)
else:
    print("Smallest number is:", c)
# Out:
# Enter first number: 2
# Enter second number: 5
# Enter third number: 7
# Smallest number is: 2

# %%
#Check Whether a Number is Positive, Negative, or Zero

num = int(input("Enter a number:"))

if num > 0:
  print("Positive Number")
elif num < 0:
  print("Negative Number")
else:
  print("Zero")
# Out:
# Enter a number:0
# Zero

# %%
#Check Whether a Number is Divisible by 5 and 11

num = int(input("Enter a number:"))

if num % 5 == 0 and num % 11 == 0:
  print("Number is divisible by 5 and 11")
else:
  print("Number is not divisible by 5 and 11")
# Out:
# Enter a number:55
# Number is divisible by 5 and 11

# %%
#Find the Factorial of a Number

num = int(input("Enter a number"))
factorial = 1

for i in range(1, num+1):
  factorial *= i

print("Factorial of", num, "is", factorial)
# Out:
# Enter a number5
# Factorial of 5 is 120

# %%
#Print the Multiplication Table of a Number

num = int(input("Enter a number: "))

for i in range(1, 11):
    print(f"{num} x {i} = {num * i}")
# Out:
# Enter a number: 12
# 12 x 1 = 12
# 12 x 2 = 24
# 12 x 3 = 36
# 12 x 4 = 48
# 12 x 5 = 60
# 12 x 6 = 72
# 12 x 7 = 84
# 12 x 8 = 96
# 12 x 9 = 108
# 12 x 10 = 120

# %%
#Find the Sum of the First N Natural Numbers

n = int(input("Enter a number: "))

total = 0

for i in range(1, n + 1):
    total += i

print("Sum of first", n, "natural numbers is:", total)
# Out:
# Enter a number: 22
# Sum of first 22 natural numbers is: 253

# %%
#Find the Sum of Even Numbers from 1 to N

n = int(input("Enter a number: "))

total = 0

for i in range(1, n + 1):
    if i % 2 == 0:
        total += i

print("Sum of even numbers from 1 to", n, "is:", total)
# Out:
# Enter a number: 5
# Sum of even numbers from 1 to 5 is: 6
